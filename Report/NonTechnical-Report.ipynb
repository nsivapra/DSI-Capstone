# %% [markdown]
# # Number of Refugees Accepted by Country

# %% [markdown]
# The definition of a refugee, according to the 1967 Protocol Relating to the Status of Refugees, is an individual who due to the fear of being persecuted for reasons of race, religion, nationality, membership of a political group, is outside his/her national country. Most likely they cannot return back home or are afraid to do so. People who move in groups to avoid war or civil conflict are often considered as refugees. A refugee isn't an individual who is stateless or denied entrance into a country. Instead the term "internally displaced people" (IDP) is used to define those individuals who may have moved for the same reasons as refugees but have not crossed the border.
#
# Recently Europe had a migration crisis, in which more than a million refugees crossed into Europe, causing a division in the European Union regarding the best way to deal with resettling people. According to the UNHCR, the top three nationalities of the refugees, between January 2015 and March 2016 were Syria, Afghan, and Iraq. In 2015 the demographic of refugees and migrants, were 58% men, 17% women, and 25% children. The number of deaths hit an all time high in April 2015, when five boats carrying 2000 migrants to Europe sank in the Mediterranean Sea, in which the death toll was estimated at 1,200 people.
#
# The Syrian Conflict has been an ongoing issue in which 250,000 citizens have lost their lives over a war that started with an armed conflict. Similarly, there have been multiple civil wars and protests that have led citizens to find asylum in different countries. After reading into these conflicts, I decided to look into the recent trends in the acceptance of refugees. Previously, there have been issues with refugees being treated poorly, and lack of a safe community. By looking into a country's profile, including the population, murder rate by 1000, poverty, etc. I hope to be able to see the relation between these variables and the refugees in 2015.

# %% [markdown]
# # Datasets

# %% [markdown]
# The dataset was created by web scrapping data from UNHCR, World Bank and multiple websites. The dataset originally contained information about Refugees in 2010, 2015, Countries, Continent, Murder Rate out of 1000, Children who dropped out of school which is out of 1000, and Government. I later decided to look into the Economic and Geographic aspect of the countries, by including GDP in million of US Dollars, Immigrants, Rainfall in ml, Population Density, Population, Area, Female population distribution, Male population distribution, recent Famine Strike (1 for yes, and 0 for no), and recent Civil War (1 for yes, and 0 for no). I believed these variables would be beneficial in showing the trends in the number of refugees, as it includes the geographic, economic, and political aspect of each country.

# %% [markdown]
# - Refugees 2010 & 2015: http://popstats.unhcr.org/en/persons_of_concern
# - Continent: https://en.wikipedia.org/wiki/List_of_countries_by_system_of_government
# - Murder Rate: http://www.nationmaster.com/country-info/stats/Crime/Murder-rate
# - Children: http://www.nationmaster.com/country-info/stats/Education/Children-out-of-school%2C-primary-per-1000
# - Government: https://en.wikipedia.org/wiki/List_of_countries_by_system_of_government
# - GDP: http://databank.worldbank.org/data/download/GDP.pdf
# - Immigrants: https://en.wikipedia.org/wiki/List_of_countries_by_immigrant_population
# - Rain: http://www.nationmaster.com/country-info/stats/Geography/Average-precipitation-in-depth/Mm-per-year
# - Density/Population/Area: http://www.worldatlas.com/aatlas/populations/ctypopls.htm
# - Famine: http://www.cs.mcgill.ca/~rwest/link-suggestion/wpcd_2008-09_augmented/wp/l/List_of_famines.htm
# - Civil War: https://en.wikipedia.org/wiki/List_of_civil_wars
# - Poverty: http://www.indexmundi.com/g/r.aspx?v=69

# %% [markdown]
# # Cleaning of Data

# %% [markdown]
# The cleaning of data involved scraping data from the World Bank, UNHCR, and Wikipedia charts and saving them as dataframes. Each data frame was later cleaned by changing the string numeric types to integers, and removing additional characters from the list. One main issue I dealt with was merging all the individual data frames together, as the country's names were spelt differently in each data frame. By modifying the country's name to match across the dataframes I was able to successfully merge 10 data frames in a main dataframe that would be used in the visualization. I later removed the rows that contained all missing data as it wouldn't be helpful in modeling, and inputted the missing cells with the mean of the column except for the binary values which were 0. The reason I didn't drop all the missing cells was to prevent the loss of important data as some rows were only missing one or two variables.

# %% [markdown]
# # Visualizations

# %%
from IPython.display import Image
Image(filename='../Images/HeatMap.png')

# %% [markdown]
# The heatmap above is a visualization that looks into the relationship between every numeric variable. The scale on the right tells us what each color represents in terms of the slope. A dark red color represents a strong positive relationship, while a dark blue color represents a strong negative relationship. For example, poverty and children out of school, have a moderately positive slope, while GDP and Poverty have a moderately negative relationship.

# %%
Image(filename='../Images/Rain-Ref.png')

# %% [markdown]
# This jointplot looks into correlation and the distribution of values in Rainfall and Refugees in 2015. Based on the slope we can say the variables are correlated negatively. The histograms above show the distribution of the values, which would be helpful in determining the mean. We can estimate the mean for the Rainfall to be around 500 based on the histogram.

# %%
Image(filename='../Images/Imm-Ref.png')

# %% [markdown]
# The jointplot above shows the relationship between Immigrants and Refugees in 2015. Looking at the values and slope we can say Immigrants and Refugees are correlated in a moderate positive manner. Based on the histogram we can say most of the Immigrants and Refugees are between 0 and 10000000.

# %%
Image(filename='../Images/Continent.png')

# %% [markdown]
# The Bar chart above shows the relationship between the continent and the number of Refugees in 2010, and 2015. I included this group by to see if location plays a role in the number of refugees accepted. Based on the results we can say Asia accepts the most refugees in 2010 and 2015. Oceania accepted the least number of refugees in 2010, while North America accepted the least refugees in 2015.

# %%
Image(filename='../Images/Government.png')

# %% [markdown]
# The Bar chart above shows the relationship between the government type and the number of Refugees in 2010 and 2015. According the chart, Absolute Monarcy took the least number in 2010, and 2015, while Republic took the most in 2010 and 2015. A country of the type constitutional monarchy had a slight increase in acceptance, while Republic had a huge increase between those years.

# %%
Image(filename='../Images/Line.png')

# %% [markdown]
# The line graph shows the relationship between the Murder Rate and Children out of school by continent. We can assume Europe to be the safest continent as it contains the least Murder and children out of school, while North America and Africa might be the unsafest continent. Africa has the highest children out of school while North America has the highest Murder Rate.

# %%
Image(filename='../Images/GDP-Imm.png')

# %% [markdown]
# This Bar chart looks into the GDP and number of Immigrants by Continent. According to the chart Africa has the lowest GDP and accepted the least Immigrants. While North America has the highest GDP and accepted the most Immigrants. Based on the chart we could say both variables have a positive correlation.

# %%
Image(filename='../Images/Country.png')

# %% [markdown]
# The Bar chart above looks into all the countries with most than 100000 Refugees in 2010 and 2015. Based on the visual Pakistan accepted less in 2015 compared to 2010, while Ethiopia and Cameroon had an increase in refugees accepted. Both China and Bangladesh accepted roughly the same number in 2010 and 2015.

# %%
Image(filename='../Images/Pairplot.png')

# %% [markdown]
# The pairplot above looks into the correlation between Refugees_2010, Refugees_2015, Population, Famine, Female, Male, Area, and Murder Rate. I choose these variables as most of them will be used in the models, and I felt these variables would best predict the number of Refugees in each country. The diagonal cells are histograms that show the distribution of the variables, while the rest of the cells are scatter plot that show the correlation between the variables.

# %% [markdown]
# # Models

# %% [markdown]
# The linear regression model is helpful in predicting the target variable (Number of Refugees in 2015) given the predictor variables(Number of Refugees in 2010, Population, Immigrants, Famine in the past 15 years, Female and Male population).
#
# The logistic model is similar to a linear model except it predicts non numeric types, in this case I will be predicting the Continent. The model looks into the continent of a country based on the number of Refugees in 2010, 2015, Murder Rate, Children out of school, Area, Female population, Male population, and Famine strikes. I also set variables that will later be used in the ROC and PR curves to predict Civil War and Famine. I used the number of Refugees in 2010, 2015, Murder Rate, Children out of school, and Area to predict either Civil War or Famine.
#
# Additional I created a PCA model that creates components based on the predictor variable to predict the Number of Refugees in 2015. The final model will be a decision tree that visually looks into the important variables that help predict the Continents and number of Refugees. It is a helpful model in seeing the different paths that could be taken to achieve the best score.

# %%
Image(filename='../Images/Civil.png')

# %% [markdown]
# The ROC curve is a metric that looks into the False Positive Rate (when the model predicts civil war and it is not civil war) vs the True Positive Rate (when the model predicts civil war and it is civil war). It is helpful in seeing whether the model performs better than random guessing, which is seen by the baseline accuracy. The AUC can determine whether the classifier is good when it approaches 1, and not so good when it approaches 0. Based on the AUC score of 0.86 we can conclude the predictor variables are helpful in predicting recent civil wars.

# %%
Image(filename='../Images/Famine.png')

# %% [markdown]
# This ROC curve looks into the false positive rate (model predicts Famine when in truth it is not Famine) vs the true positive rate (model predicts Famine and it is Famine). Based on the curve being above the baseline, we can conclude the model is doing better than randomly guessing. The AUC of 0.85 tells us that the predictor variables are helpful in predicting recent Famine.

# %%
Image(filename='../Images/Civil_War.png')

# %% [markdown]
# The precision recall curve looks at the recall (how often the model predicts civil war when it is civil war) vs the precision (when the model predicts civil war how often is it correct). The f1 score is a metric that calculates accuracy based on the recall and precision. Based on the f1 score we can conclude the model predicts civil war with an average accuracy.

# %%
Image(filename='../Images/Recent_Famine.png')

# %% [markdown]
# This PR curve looks into the recall and precision of recent famine. Based on the curve we can see as the recall increases the precision slowly decreases. The PRAUC is helpful in determining the accuracy of the model in predicting the target variable. Looking at the score of 0.52 we can conclude the accuracy of predicting famine is moderate.

# %%
Image(filename='../Images/pca_image.png')

# %% [markdown]
# A simple way to think about PCA, is a transformation that transforms the coordinate system so the axes represent the data for each variable. In the case of the linear model, I looked into the number of refugees in 2010, Rainfall, Population, whether a country had a recent famine, Female and Male population. By using PCA, we can reduce the number of dimensions and the lose the least amount of variance in our data. The plot above shows the relationship between each component against itself, in which the diagonal values are histograms and the rest are pairplots.

# %%
Image(filename='../Images/decision_cont.png')

# %% [markdown]
# The tree above shows the best path to find the variables that suit the model to predict the continent of a country. Values traversing towards the left means that in the previous condition it was true, while a value traversing towards the right means that the condition was false. The sample's value is the number of observations in that node before splitting. Based on the entropy (impurity) value of 0, we can say Children out of school, Murder Rate, and the number of Refugees in 2010 were helpful in finding the variables to achieve the lowest entropy.

# %%
Image(filename='../Images/decision_ref.png')

# %% [markdown]
# According to the decision tree above, the best path to achieving the highest expected value and a low mse value contains the variable Refugees 2010 and Population. Another path to a high expected value node, looks into the Density, Population, and Refugees_2010. Based on the paths were can conclude Population, Density, and Refugees in 2010 were the main variables that affected the decision tree.

# %% [markdown]
# # World Maps

# %%
# %%HTML
# <iframe
#   src="https://public.tableau.com/profile/publish/Refugees_2010/Sheet2#!/publish-confirm"
#   width="1000px"
#   height="1000px">
# </iframe>
#
# #Note the tableau visualization doesn't show up on github.
# Out:
# <iframe
#   src="https://public.tableau.com/profile/publish/Refugees_2010/Sheet2#!/publish-confirm"
#   width="1000px"
#   height="1000px">
# </iframe>
#
# #Note the tableau visualization doesn't show up on github.

# %% [markdown]
# The tableau visualization above shows a gradient map that visualizes the number of refugees in 2010 and 2015. As the color gets darker the number of refugees in the country is higher and vice versa. By moving a mouse over the country we can see the values associated with the country. Based on the results we can see a huge increase in refugees in Turkey between 2010 and 2015. Syria and Canada had a drop in the number of refugees accepted, primarily due to conflicts and political wars (Syria War).

# %% [markdown]
# # Conclusion

# %% [markdown]
# Based on the country's profile we can say there is an impact on the number of refugees who will find asylum in the country. If there a high number of refugees in 2010, GDP, and number of immigrants there is a higher chance of refugees in 2015. If there is a high number of Rainfall, and Murder Rate there is a chance of a descent between 2010 and 2015.
#
# Considering the European crisis and recent incidents with transportation there is a higher number of refugees finding asylum in Asia, and South American countries. Based on the tableau map visualization there is a possibility that countries in North America and Oceania will start accepting refugees to prevent an overflow in the other continents. By reducing racism, setting strict laws to the natives, and providing a safer environment in other countries, there is a chance more refugees would seek to find asylum.
